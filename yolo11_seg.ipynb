# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SKJUsABxnd1bncMso3nN")
project = rf.workspace("arman-fgtet").project("seg1-pdagd")
version = project.version(2)
dataset = version.download("coco-segmentation")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 122.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to seg1-2 in coco-segmentation:: 100%|██████████| 985/985 [00:00<00:00, 8734.03it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 112.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics.data.converter import convert_coco
for i in ["test", "train", "valid"]:
    convert_coco(labels_dir=f"seg1-2/{i}/", save_dir=f"datasets/{i}/", use_segments=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Annotations /content/seg1-2/test/_annotations.coco.json: 100%|██████████| 40/40 [00:00<00:00, 3792.92it/s]
# COCO data converted successfully.
# Results saved to /content/datasets/test
# Annotations /content/seg1-2/train/_annotations.coco.json: 100%|██████████| 855/855 [00:00<00:00, 4310.45it/s]
# COCO data converted successfully.
# Results saved to /content/datasets/train
# Annotations /content/seg1-2/valid/_annotations.coco.json: 100%|██████████| 82/82 [00:00<00:00, 4141.28it/s]
# COCO data converted successfully.
# Results saved to /content/datasets/valid

# %%
import shutil
for i in ["test", "train", "valid"]:
    shutil.copytree(f"datasets/{i}/labels/_annotations.coco", f"datasets/{i}/labels", dirs_exist_ok=True)
    shutil.rmtree(f"datasets/{i}/labels/_annotations.coco")

# %%
import os
for i in ["test", "train", "valid"]:
    shutil.copytree(f"seg1-2/{i}/", f"datasets/{i}/images/", dirs_exist_ok=True)
    os.remove(f"datasets/{i}/images/_annotations.coco.json")

# %%
# !yolo segment train data=data.yaml model=yolo11s-seg.pt epochs=40 imgsz=320

# %%
# !apt install rar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   rar
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 389 kB of archives.
# After this operation, 1,400 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 rar amd64 2:6.23-1~22.04.1 [389 kB]
# Fetched 389 kB in 2s (243 kB/s)
# Selecting previously unselected package rar.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../rar_2%3a6.23-1~22.04.1_amd64.deb ...
# Unpacking rar (2:6.23-1~22.04.1) ...
# Setting up rar (2:6.23-1~22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !rar a train3.rar "/content/runs/segment/train3"

# %%
# !rar a dataset_yolo11_maghale5.rar "/content/datasets"
# Out:
# RAR 6.23   Copyright (c) 1993-2023 Alexander Roshal   1 Aug 2023
# Trial version             Type 'rar -?' for help
#
# Evaluation copy. Please register.
#
# Creating archive dataset_yolo11_maghale5.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
